# %%
import pandas as pd
from google.cloud import bigquery

# %%
def fetch_and_save_data(client, org_list, time_period, dates):
    """
    Queries the GitHub archive dataset for specified repositories and dates, then saves the results in JSON files.

    Parameters:
        client (bigquery.Client): The BigQuery client used to execute queries.
        repository_list (str): A string of repository names formatted for SQL IN clause.
        time_period (str): The table suffix in BigQuery dataset (e.g., 'day', 'month').
        dates (list): A list of date strings in 'YYYYMMDD' format.

    Outputs:
        JSON files containing query results for each specified date.
    """
    for date in dates:
        try:
            query = f"""
            SELECT *
            FROM `githubarchive.{time_period}.{date}`
            WHERE org.login IN ({org_list})
            ORDER BY created_at
            """
            print(f"Querying data for {date}...")
            query_job = client.query(query)
            result = query_job.result(timeout=300)  # Extended timeout for large queries

            print(f"Job ID: {query_job.job_id}")
            print(f"Total bytes processed (GiB): {query_job.total_bytes_processed / (1024 ** 3)}")
            print(f"Query start time: {query_job.started}")
            print(f"Query end time: {query_job.ended}")
            print(f"Duration: {query_job.ended - query_job.started}")

            df = result.to_dataframe(progress_bar_type='tqdm')
            json_filename = f'numfocus-raw-data-v2/gh_events_{date}.json'
            df.to_json(json_filename, orient='records')
            print(f"Data for {date} saved to {json_filename}")

        except bigquery.exceptions.BigQueryError as e:
            print(f"BigQuery error for {date}: {e} \n\n")
        except Exception as e:
            print(f"Unexpected error for {date}: {e} \n\n")
        finally:
            print(f"Finished processing for {date} \n\n")

# %%
# Initialize the BigQuery client
bq_client = bigquery.Client('sylvan-client-422708-d4')

# %%
# Organizations to query
orgs = "'matplotlib', 'numpy', 'pandas-dev', 'jupyter', 'ipython', 'scipy', 'nteract', 'stan-dev', 'pymc-devs', 'JuliaLang', 'jump-dev', 'PyTables', 'shogun-toolbox', 'sympy', 'FEniCS', 'yt-project', 'econ-ark', 'astropy', 'sunpy', 'QuantEcon', 'ropensci', 'openjournals', 'Cantera', 'bokeh', 'pydata', 'Blosc', 'dask', 'mlpack', 'zarr-developers', 'MDAnalysis', 'scikit-image', 'InsightSoftwareConsortium', 'Open-MBEE', 'scikit-learn', 'SciML', 'tardis-sn', 'arviz-devs', 'lfortran', 'networkx', 'OSGeo', 'sgkit-dev', 'nipy', 'napari', 'scientific-python', 'conda', 'cupy', 'gnu-octave', 'galaxyproject', 'Bioconductor', 'pybamm-team', 'WorldWideTelescope', 'spyder-ide', 'gammapy', 'geopandas', 'scverse', 'holoviz', 'petsc', 'pangeo-data', 'fortran-lang', 'conda-forge', 'openfheorg'"

# Period & dates to query
query_period = 'month'
query_dates = ['202301', '202302', '202303', '202304', '202305', '202306', 
               '202307', '202308', '202309', '202310', '202311', '202312',
               '202401', '202402', '202403', '202404', '202405', '202406']

# %%
# Execute the function
fetch_and_save_data(bq_client, orgs, query_period, query_dates)
# Out:
# Querying data for 202301...
# Job ID: b726ee6e-3048-4f06-bca5-14bd56f1a2ce
# Total bytes processed (GiB): 466.9329786458984
# Query start time: 2024-07-08 09:37:27.006000+00:00
# Query end time: 2024-07-08 09:37:38.391000+00:00
# Duration: 0:00:11.385000
# Downloading: 100%|█████████████████████████████████████████████████████████████|
# Data for 202301 saved to numfocus-raw-data-v2/gh_events_202301.json
# Finished processing for 202301
#
#
# Querying data for 202302...
# Job ID: ce4f9eaa-68a0-4f8c-8d2b-fc87d5f68d15
# Total bytes processed (GiB): 393.6564892306924
# Query start time: 2024-07-08 09:49:43.318000+00:00
# Query end time: 2024-07-08 09:49:57.405000+00:00
# Duration: 0:00:14.087000
# Downloading: 100%|█████████████████████████████████████████████████████████████|
# Data for 202302 saved to numfocus-raw-data-v2/gh_events_202302.json
# Finished processing for 202302
#
#
# Querying data for 202303...
# Job ID: 5dde3642-1ec2-4c13-a644-d4e4c00165f8
# Total bytes processed (GiB): 429.3616208154708
# Query start time: 2024-07-08 10:01:21.273000+00:00
# Query end time: 2024-07-08 10:01:38.385000+00:00
# Duration: 0:00:17.112000
# Downloading: 100%|█████████████████████████████████████████████████████████████|
# Data for 202303 saved to numfocus-raw-data-v2/gh_events_202303.json
# Finished processing for 202303
#
#
# Querying data for 202304...
# Job ID: 4e6a5ee0-2307-4fde-828c-5b89944b1db8
# Total bytes processed (GiB): 374.53132306598127
# Query start time: 2024-07-08 10:14:13.985000+00:00
# Query end time: 2024-07-08 10:14:30.876000+00:00
# Duration: 0:00:16.891000
# Downloading: 100%|█████████████████████████████████████████████████████████████|
# Data for 202304 saved to numfocus-raw-data-v2/gh_events_202304.json
# Finished processing for 202304
#
#
# Querying data for 202305...
# Job ID: ba640609-0531-4132-a6ac-328b19d17c44
# Total bytes processed (GiB): 383.0309081124142
# Query start time: 2024-07-08 10:25:11.467000+00:00
# Query end time: 2024-07-08 10:25:27.609000+00:00
# Duration: 0:00:16.142000
# Downloading: 100%|█████████████████████████████████████████████████████████████|
# Data for 202305 saved to numfocus-raw-data-v2/gh_events_202305.json
# Finished processing for 202305
#
#
# Querying data for 202306...
# Job ID: 8c5d4a6d-04a7-4a99-823e-16290b232bfa
# Total bytes processed (GiB): 362.1998591637239
# Query start time: 2024-07-08 10:36:20.820000+00:00
# Query end time: 2024-07-08 10:36:36.450000+00:00
# Duration: 0:00:15.630000
# Downloading: 100%|█████████████████████████████████████████████████████████████|
# Data for 202306 saved to numfocus-raw-data-v2/gh_events_202306.json
# Finished processing for 202306
#
#
# Querying data for 202307...
# Job ID: 5e1a22f4-01ea-4a19-b170-b8c642afb5c5
# Total bytes processed (GiB): 380.9689337229356
# Query start time: 2024-07-08 10:48:35.515000+00:00
# Query end time: 2024-07-08 10:48:51.901000+00:00
# Duration: 0:00:16.386000
# Downloading: 100%|█████████████████████████████████████████████████████████████|
# Data for 202307 saved to numfocus-raw-data-v2/gh_events_202307.json
# Finished processing for 202307
#
#
# Querying data for 202308...
# Job ID: c7ddb3f8-3d9d-4e61-9980-218f7c51f4fc
# Total bytes processed (GiB): 378.49694378860295
# Query start time: 2024-07-08 10:59:39.103000+00:00
# Query end time: 2024-07-08 10:59:50.234000+00:00
# Duration: 0:00:11.131000
# Downloading: 100%|█████████████████████████████████████████████████████████████|
# Data for 202308 saved to numfocus-raw-data-v2/gh_events_202308.json
# Finished processing for 202308
#
#
# Querying data for 202309...
# Job ID: 986b146b-5656-4d9f-96b3-59ac5aff12b4
# Total bytes processed (GiB): 374.4011639151722
# Query start time: 2024-07-08 11:11:38.114000+00:00
# Query end time: 2024-07-08 11:11:51.409000+00:00
# Duration: 0:00:13.295000
# Downloading: 100%|█████████████████████████████████████████████████████████████|
# Data for 202309 saved to numfocus-raw-data-v2/gh_events_202309.json
# Finished processing for 202309
#
#
# Querying data for 202310...
# Job ID: 498f46e7-92c4-4aba-9c36-e4682ca50e0a
# Total bytes processed (GiB): 429.22669104859233
# Query start time: 2024-07-08 11:24:12.647000+00:00
# Query end time: 2024-07-08 11:24:36.104000+00:00
# Duration: 0:00:23.457000
# Downloading: 100%|█████████████████████████████████████████████████████████████|
# Data for 202310 saved to numfocus-raw-data-v2/gh_events_202310.json
# Finished processing for 202310
#
#
# Querying data for 202311...
# Job ID: 43367343-e4b8-4728-b747-71c281f73d58
# Total bytes processed (GiB): 414.8936837306246
# Query start time: 2024-07-08 11:37:35.875000+00:00
# Query end time: 2024-07-08 11:37:53.450000+00:00
# Duration: 0:00:17.575000
# Downloading: 100%|█████████████████████████████████████████████████████████████|
# Data for 202311 saved to numfocus-raw-data-v2/gh_events_202311.json
# Finished processing for 202311
#
#
# Querying data for 202312...
# Job ID: af7885ec-6365-4f86-a4f0-783b8cbeddeb
# Total bytes processed (GiB): 371.1910019973293
# Query start time: 2024-07-08 11:50:14.516000+00:00
# Query end time: 2024-07-08 11:50:24.672000+00:00
# Duration: 0:00:10.156000
# Downloading: 100%|█████████████████████████████████████████████████████████████|
# Data for 202312 saved to numfocus-raw-data-v2/gh_events_202312.json
# Finished processing for 202312
#
#
# Querying data for 202401...
# Job ID: 1ae8203a-6413-4b88-b58e-90c9e8402a88
# Total bytes processed (GiB): 425.40807474963367
# Query start time: 2024-07-08 12:00:59.178000+00:00
# Query end time: 2024-07-08 12:01:32.224000+00:00
# Duration: 0:00:33.046000
# Downloading: 100%|█████████████████████████████████████████████████████████████|
# Data for 202401 saved to numfocus-raw-data-v2/gh_events_202401.json
# Finished processing for 202401
#
#
# Querying data for 202402...
# Job ID: 8ef4a5e4-314c-42f2-baac-b44bd1792f50
# Total bytes processed (GiB): 431.4214790882543
# Query start time: 2024-07-08 12:14:56.408000+00:00
# Query end time: 2024-07-08 12:15:12.013000+00:00
# Duration: 0:00:15.605000
# Downloading: 100%|█████████████████████████████████████████████████████████████|
# Data for 202402 saved to numfocus-raw-data-v2/gh_events_202402.json
# Finished processing for 202402
#
#
# Querying data for 202403...
# Job ID: 69420ec9-9a36-4d9c-8df3-ebbca89ead85
# Total bytes processed (GiB): 449.17057186644524
# Query start time: 2024-07-08 12:28:28.279000+00:00
# Query end time: 2024-07-08 12:28:43.006000+00:00
# Duration: 0:00:14.727000
# Downloading: 100%|█████████████████████████████████████████████████████████████|
# Data for 202403 saved to numfocus-raw-data-v2/gh_events_202403.json
# Finished processing for 202403
#
#
# Querying data for 202404...
# Job ID: 6757cb62-bbfc-4ac2-87a1-86688b66b199
# Total bytes processed (GiB): 463.09251431841403
# Query start time: 2024-07-08 12:41:41.514000+00:00
# Query end time: 2024-07-08 12:42:13.081000+00:00
# Duration: 0:00:31.567000
# Downloading: 100%|█████████████████████████████████████████████████████████████|
# Data for 202404 saved to numfocus-raw-data-v2/gh_events_202404.json
# Finished processing for 202404
#
#
# Querying data for 202405...
# Job ID: f081774e-d829-488c-8661-2d3ca5b20ecf
# Total bytes processed (GiB): 450.02658155281097
# Query start time: 2024-07-08 12:54:35.158000+00:00
# Query end time: 2024-07-08 12:55:06.034000+00:00
# Duration: 0:00:30.876000
# Downloading: 100%|█████████████████████████████████████████████████████████████|
# Data for 202405 saved to numfocus-raw-data-v2/gh_events_202405.json
# Finished processing for 202405
#
#
# Querying data for 202406...
# Job ID: 84d278aa-d6e1-4a79-ac72-fc64e1d98a68
# Total bytes processed (GiB): 424.775220640935
# Query start time: 2024-07-08 13:08:45.016000+00:00
# Query end time: 2024-07-08 13:09:11.301000+00:00
# Duration: 0:00:26.285000
# Downloading: 100%|█████████████████████████████████████████████████████████████|
# Data for 202406 saved to numfocus-raw-data-v2/gh_events_202406.json
# Finished processing for 202406
